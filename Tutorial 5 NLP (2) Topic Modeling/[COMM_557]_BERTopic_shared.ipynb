# %% [markdown]
# # BERTopic Tutorial
# Grootendorst, M. (2022). BERTopic: Neural topic modeling with a class-based TF-IDF procedure. arXiv preprint arXiv:2203.05794.
#
# https://arxiv.org/pdf/2203.05794.pdf
#
# Document Embedding (BERT) > Dimension Reduction (UMAP) > Clustering (HDBSCAN) > Topic Representation (TF/IDF)

# %% [markdown]
# # **Installing BERTopic**
#
# We start by installing BERTopic from PyPi:

# %%
# %%capture
# !pip install bertopic

# %% [markdown]
# # Data
# For this example, we use a large Kaggle dataset with 20 topics for news headlines from Huffington Post.
#
# https://www.kaggle.com/datasets/rmisra/news-category-dataset

# %%
import pandas as pd
url = 'https://github.com/EunCheolChoi0123/COMM557Tutorial/raw/main/Tutorial%205%20NLP%20(2)%20Topic%20Modeling/news_headline_sample.csv'
df  = pd.read_csv(url)
df = df[~df.headline.isna()]
df = df.sample(frac = 0.1)
docs = df.headline.to_list()

# %%
len(docs)
# Out:
# 20952

# %%
df.category.value_counts()
# Out:
# category
# POLITICS          3602
# WELLNESS          1798
# ENTERTAINMENT     1747
# TRAVEL             986
# STYLE & BEAUTY     951
# PARENTING          907
# HEALTHY LIVING     684
# QUEER VOICES       656
# FOOD & DRINK       596
# BUSINESS           568
# COMEDY             535
# SPORTS             514
# BLACK VOICES       506
# HOME & LIVING      450
# WOMEN              376
# PARENTS            367
# WEDDINGS           357
# CRIME              356
# DIVORCE            336
# THE WORLDPOST      334
# IMPACT             321
# WORLD NEWS         314
# GREEN              289
# MEDIA              282
# RELIGION           274
# WORLDPOST          266
# WEIRD NEWS         265
# TASTE              232
# TECH               215
# STYLE              208
# SCIENCE            201
# MONEY              183
# ARTS               146
# ARTS & CULTURE     143
# GOOD NEWS          142
# FIFTY              133
# COLLEGE            128
# U.S. NEWS          124
# ENVIRONMENT        124
# LATINO VOICES      122
# EDUCATION          109
# CULTURE & ARTS     105
# Name: count, dtype: int64

# %% [markdown]
# # **Topic Modeling**
#
# In this example, we will go through the main components of BERTopic and the steps necessary to create a strong topic model.

# %% [markdown]
# ## Training
#
# We start by instantiating BERTopic. We set language to `english` since our documents are in the English language. If you would like to use a multi-lingual model, please use `language="multilingual"` instead.
#
# We will also calculate the topic probabilities. However, this can slow down BERTopic significantly at large amounts of data (>100_000 documents). It is advised to turn this off if you want to speed up the model.

# %%
# %%time
# This line took 3 minutes on T4
from bertopic import BERTopic

topic_model = BERTopic(language="english", calculate_probabilities=True, verbose=True)
topics, probs = topic_model.fit_transform(docs)
# Out:
# 2024-10-01 00:44:16,222 - BERTopic - Embedding - Transforming documents to embeddings.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/655 [00:00<?, ?it/s]
# 2024-10-01 00:44:31,989 - BERTopic - Embedding - Completed ✓
# 2024-10-01 00:44:31,990 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-10-01 00:45:12,530 - BERTopic - Dimensionality - Completed ✓
# 2024-10-01 00:45:12,532 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-10-01 00:46:45,417 - BERTopic - Cluster - Completed ✓
# 2024-10-01 00:46:45,430 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-10-01 00:46:45,975 - BERTopic - Representation - Completed ✓
# CPU times: user 2min 50s, sys: 3.41 s, total: 2min 53s
# Wall time: 3min 5s

# %% [markdown]
# ## Extracting Topics
# After fitting our model, we can start by looking at the results. Typically, we look at the most frequent topics first as they best represent the collection of documents. -1 refers to all outliers. We will reduce outliers by assiging documents to topics that has similar embeddings.

# %%
freq = topic_model.get_topic_info(); freq.head(5)
# Out:
#    Topic  Count                                    Name  \
# 0     -1   9461                         -1_the_of_to_in
# 1      0    873               0_recipes_food_eat_recipe
# 2      1    216  1_wedding_weddings_proposal_engagement
# 3      2    211     2_divorce_marriage_married_cheating
# 4      3    190              3_women_womens_qa_business
#
#                                       Representation  \
# 0  [the, of, to, in, is, and, on, for, trump, video]
# 1  [recipes, food, eat, recipe, cooking, thanksgi...
# 2  [wedding, weddings, proposal, engagement, coup...
# 3  [divorce, marriage, married, cheating, divorce...
# 4  [women, womens, qa, business, gender, feminism...
#
#                                  Representative_Docs
# 0  [What My Son Has Taught Me in the First 100 Da...
# 1  [How Food Photos Can Make Us Healthier, Angel ...
# 2  [Real Weddings: Couples Who Got Married This W...
# 3  [Divorce Confidential: A Cheating Heart and It...
# 4  [International Women's Day 2012: Advancing Wom...

# %%
# Reduce outliers using the `embeddings` strategy
new_topics = topic_model.reduce_outliers(docs, topics, strategy="embeddings")

# %%
topic_model.update_topics(docs, topics=new_topics)
# Out:
# 2024-10-01 00:47:20,512 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.

# %%
freq = topic_model.get_topic_info(); freq.head(5)
# Out:
#    Topic  Count                                 Name  \
# 0      0    940            0_recipes_food_recipe_eat
# 1      1    231   1_wedding_weddings_proposal_couple
# 2      2    237  2_divorce_marriage_married_cheating
# 3      3    274             3_women_womens_gender_qa
# 4      4    268               4_gay_lgbt_lgbtq_queer
#
#                                       Representation  \
# 0  [recipes, food, recipe, eat, cooking, thanksgi...
# 1  [wedding, weddings, proposal, couple, engageme...
# 2  [divorce, marriage, married, cheating, divorce...
# 3  [women, womens, gender, qa, business, female, ...
# 4  [gay, lgbt, lgbtq, queer, pride, rights, commu...
#
#                                  Representative_Docs
# 0  [How Food Photos Can Make Us Healthier, Angel ...
# 1  [Real Weddings: Couples Who Got Married This W...
# 2  [Divorce Confidential: A Cheating Heart and It...
# 3  [International Women's Day 2012: Advancing Wom...
# 4  [Why I Don't Celebrate LGBT Pride Month, Gay P...

# %% [markdown]
# Next, let's take a look at a frequent topic that were generated:

# %%
topic_model.get_topic(0)  # Select the most frequent topic
# Out:
# [('recipes', 0.025492883277435693),
#  ('food', 0.024281004804677698),
#  ('recipe', 0.016049274898110404),
#  ('eat', 0.015595100153641257),
#  ('cooking', 0.013295814590861882),
#  ('thanksgiving', 0.012882214132455272),
#  ('foods', 0.01221813199740809),
#  ('healthy', 0.010656163203564835),
#  ('best', 0.009299870526515121),
#  ('cake', 0.009144710599689465)]

# %% [markdown]
# **NOTE**: BERTopic is stocastich which mmeans that the topics might differ across runs. This is mostly due to the stocastisch nature of UMAP.

# %% [markdown]
# ## Attributes
#
# There are a number of attributes that you can access after having trained your BERTopic model:
#
#
# | Attribute | Description |
# |------------------------|---------------------------------------------------------------------------------------------|
# | topics_               | The topics that are generated for each document after training or updating the topic model. |
# | probabilities_ | The probabilities that are generated for each document if HDBSCAN is used. |
# | topic_sizes_           | The size of each topic                                                                      |
# | topic_mapper_          | A class for tracking topics and their mappings anytime they are merged/reduced.             |
# | topic_representations_ | The top *n* terms per topic and their respective c-TF-IDF values.                             |
# | c_tf_idf_              | The topic-term matrix as calculated through c-TF-IDF.                                       |
# | topic_labels_          | The default labels for each topic.                                                          |
# | custom_labels_         | Custom labels for each topic as generated through `.set_topic_labels`.                                                               |
# | topic_embeddings_      | The embeddings for each topic if `embedding_model` was used.                                                              |
# | representative_docs_   | The representative documents for each topic if HDBSCAN is used.                                                |
#
# For example, to access the predicted topics for the first 10 documents, we simply run the following:

# %%
topic_model.topics_[:10]
# Out:
# [79, 51, 14, 258, 4, 54, 23, 11, 76, 39]

# %% [markdown]
# # **Visualization**
# There are several visualization options available in BERTopic, namely the visualization of topics, probabilities and topics over time. Topic modeling is, to a certain extent, quite subjective. Visualizations help understand the topics that were created.

# %% [markdown]
# ## Visualize Topics
# After having trained our `BERTopic` model, we can iteratively go through perhaps a hundred topic to get a good
# understanding of the topics that were extract. However, that takes quite some time and lacks a global representation.
# Instead, we can visualize the topics that were generated in a way very similar to
# [LDAvis](https://github.com/cpsievert/LDAvis):

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="693d5407-dbfb-4093-b6a9-99ef09a5928d" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("693d5407-dbfb-4093-b6a9-99ef09a5928d")) {                    Plotly.newPlot(                        "693d5407-dbfb-4093-b6a9-99ef09a5928d",                        [{"customdata":[[0,"recipes | food | recipe | eat | cooking",940],[1,"wedding | weddings | proposal | couple | engagement",231],[2,"divorce | marriage | married | cheating | divorced",237],[3,"women | womens | gender | qa | business",274],[4,"gay | lgbt | lgbtq | queer | pride",268],[5,"workout | fitness | exercise | workouts | training",193],[6,"dog | dogs | cat | pet | cats",210],[7,"hair | makeup | beauty | skin | braid",198],[8,"sleep | apnea | sleeping | study | better",169],[9,"sexual | assault | rape | harassment | misconduct",252],[10,"mom | mothers | moms | mother | motherhood",236],[11,"russia | email | russian | putin | fbi",232],[12,"obamacare | care | health | repeal | insurance",156],[13,"donald | trump | trumps | twitter | trevor",337],[14,"isis | syria | aleppo | syrian | islamic",143],[15,"police | shooting | cops | officer | man",213],[16,"fashion | week | style | stylelist | 2012",206],[17,"hurricane | fire | storm | flooding | storms",152],[18,"dress | photos | carpet | red | poll",277],[19,"gun | guns | nra | control | shooting",142],[20,"health | doctor | medicine | doctors | care",153],[21,"beer | drink | cocktails | cocktail | alcohol",121],[22,"cancer | breast | donnas | prostate | diagnosis",109],[23,"primary | gop | race | republican | candidate",203],[24,"nfl | bowl | super | football | player",143],[25,"covid19 | coronavirus | flu | vaccine | pandemic",115],[26,"korea | north | jong | un | missile",98],[27,"be


# %%
topic_model.get_topic(0)   # We select topic that we viewed before
# Out:
# [('the best', 0.005726331944734901),
#  ('to make', 0.00539328563229145),
#  ('to eat', 0.005381521797903613),
#  ('recipe of the', 0.004990172553730075),
#  ('recipe of', 0.004990172553730075),
#  ('how to', 0.004886302758439902),
#  ('how to make', 0.004189469312446796),
#  ('recipes that', 0.004099578447577993),
#  ('ice cream', 0.003724536182291051),
#  ('of the day', 0.0036192806607268212)]

# %% [markdown]
# ## Topic Reduction
# We can also reduce the number of topics after having trained a BERTopic model. The advantage of doing so,
# is that you can decide the number of topics after knowing how many are actually created. It is difficult to
# predict before training your model how many topics that are in your documents and how many will be extracted.
# Instead, we can decide afterwards how many topics seems realistic:

# %%
topic_model.reduce_topics(docs, nr_topics=60)
# Out:
# 2024-10-01 00:48:42,206 - BERTopic - Topic reduction - Reducing number of topics
# 2024-10-01 00:48:43,885 - BERTopic - Topic reduction - Reduced number of topics from 289 to 60

# %%
# Access the newly updated topics with:
print(topic_model.topics_)
# Out:
# [1, 2, 12, 0, 6, 37, 1, 1, 19, 1, 4, 14, 1, 10, 3, 2, 8, 11, 0, 0, 1, 4, 1, 2, 12, 0, 3, 35, 10, 4, 14, 29, 55, 1, 0, 0, 5, 1, 5, 18, 1, 2, 5, 0, 0, 3, 14, 4, 34, 0, 1, 2, 3, 8, 13, 23, 9, 1, 17, 2, 1, 0, 0, 1, 0, 1, 35, 21, 39, 25, 39, 3, 1, 2, 1, 0, 0, 8, 1, 0, 12, 5, 9, 9, 36, 0, 4, 0, 17, 14, 0, 45, 3, 35, 2, 26, 2, 0, 39, 53, 1, 2, 1, 0, 17, 16, 37, 0, 23, 14, 1, 22, 2, 21, 5, 0, 3, 5, 2, 7, 2, 3, 14, 33, 0, 14, 2, 1, 12, 39, 1, 0, 1, 10, 34, 4, 7, 37, 3, 3, 0, 38, 0, 0, 2, 13, 55, 34, 0, 5, 2, 2, 0, 0, 37, 0, 7, 1, 7, 0, 1, 1, 5, 4, 36, 2, 46, 6, 3, 38, 21, 4, 0, 10, 14, 4, 8, 6, 0, 16, 40, 0, 3, 5, 8, 33, 2, 9, 21, 1, 15, 0, 0, 13, 4, 16, 7, 1, 2, 5, 20, 12, 6, 9, 26, 37, 32, 32, 13, 2, 19, 2, 3, 2, 37, 0, 0, 0, 3, 1, 10, 1, 11, 18, 10, 17, 2, 1, 26, 12, 0, 2, 1, 30, 25, 0, 2, 6, 12, 2, 0, 6, 25, 4, 36, 0, 1, 0, 0, 2, 32, 14, 0, 4, 19, 16, 17, 2, 8, 18, 10, 0, 1, 1, 21, 23, 16, 6, 8, 6, 0, 0, 1, 7, 46, 33, 0, 2, 0, 13, 5, 6, 6, 17, 11, 4, 10, 3, 3, 14, 1, 0, 41, 2, 10, 0, 10, 6, 2, 9, 0, 2, 4, 1, 0, 18, 3, 5, 0, 1, 1, 4, 0, 0, 42, 0, 2, 0, 14, 26, 1, 1, 3, 0, 21, 3, 0, 1, 5, 14, 7, 10, 29, 0, 2, 15, 15, 2, 8, 31, 23, 1, 4, 2, 0, 8, 1, 5, 3, 7, 22, 27, 1, 7, 10, 0, 6, 10, 0, 1, 11, 7, 2, 3, 0, 42, 5, 1, 2, 16, 23, 4, 0, 4, 15, 5, 3, 36, 24, 7, 29, 0, 1, 18, 3, 44, 0, 3, 2, 3, 24, 3, 23, 41, 3, 7, 17, 7, 6, 19, 0, 59, 1, 3, 39, 3, 0, 35, 4, 13, 0, 3, 2, 3, 2, 2, 9, 0, 7
 7, 1, 36, 11, 34, 12, 5, 4, 4, 1, 16, 5, 11, 8, 21, 31, 4, 0, 46, 9, 3, 0, 0, 5, 35, 10, 8, 35, 9, 40, 0, 18, 2, 0, 8, 0, 17, 8, 4, 11, 0, 7, 13, 27, 4, 21, 0, 37, 11, 0, 28, 50, 26, 1, 20, 32, 32, 25, 1, 24, 44, 32, 36, 2, 0, 28, 13, 21, 14, 15, 4, 0, 5, 16, 1, 16, 0, 11, 0, 0, 26, 7, 8, 1, 2, 4, 3, 9, 4, 3, 10, 1, 25, 10, 9, 2, 0, 0, 22, 50, 3, 33, 32, 0, 19, 6, 1, 2, 0, 19, 0, 14, 20, 4, 3, 22, 0, 5, 11, 23, 1, 51, 25, 7, 3, 9, 2, 14, 5, 0, 37, 13, 0, 1, 1, 13, 1, 16, 0, 11, 27, 2, 19, 15, 1, 3, 7, 21, 1, 38, 5, 18, 0, 3, 7, 25, 7, 13, 0, 3, 2, 1, 0, 1, 1, 36, 36, 1, 11, 2, 9, 10, 0, 32, 0, 8, 6, 1, 1, 0, 30, 3, 16, 33, 3, 38, 0, 10, 1, 16, 32, 4, 0, 7, 42, 3, 25, 7, 2, 3, 44, 6, 1, 6, 0, 40, 5, 8, 10, 28, 0, 20, 0, 18, 16, 0, 0, 44, 0, 3, 1, 24, 11, 3, 15, 0, 13, 1, 12, 25, 12, 14, 1, 23, 11, 0, 1, 4, 5, 3, 15, 1, 24,  ...

# %%
topic_model.visualize_barchart(top_n_topics=5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="50c73bb5-4b9f-4517-a678-1837f9f0d0b5" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("50c73bb5-4b9f-4517-a678-1837f9f0d0b5")) {                    Plotly.newPlot(                        "50c73bb5-4b9f-4517-a678-1837f9f0d0b5",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.0035238416974858167,0.0036232179682253595,0.0037669844816284877,0.004242291132480838,0.006068982444469603],"y":["in the  ","the best  ","of the  ","ways to  ","how to  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.006079502490035426,0.006216822261820599,0.0064619040124299495,0.007528705212898274,0.015236978456663634],"y":["white house  ","donald trumps  ","bernie sanders  ","hillary clinton  ","donald trump  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.002892890960133232,0.0033061610972951226,0.003495561881101305,0.0036354662098581417,0.006195509013888917],"y":["lives matter  ","gun control  ","at least  ","dies at  ","dead at  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.004224331874136471,0.004591665080583121,0.004655785765795174,0.005224543187040335,0.0061113975116036945],"y":["red carpet  ","kanye west  ","miley cyrus  ","taylor swift  ","kim kardashian  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.004759378054647786,0.004759378054647786,0.0049035986756416254,0.005021366970525984,0.008901148968182285],"y":["craft of  ","craft of the  ","of the day  ","photos of  ","of the  "],"type":"bar","xaxis":"x5","yaxis":"y5"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0. ...

# %% [markdown]
# # **Search Topics**
# After having trained our model, we can use `find_topics` to search for topics that are similar
# to an input search_term. Here, we are going to be searching for topics that closely relate the
# search term "vehicle". Then, we extract the most similar topic and check the results:

# %%
similar_topics, similarity = topic_model.find_topics("vehicle", top_n=5); similar_topics
# Out:
# [41, 2, 0, 11, 5]

# %%
topic_model.get_topic(similar_topics[0])
# Out:
# [('drowsy driving', 0.018781615485527647),
#  ('uber drivers', 0.014633884988598602),
#  ('is driving', 0.014633884988598602),
#  ('driving your', 0.010270604638319894),
#  ('selfdriving cars', 0.010270604638319894),
#  ('selfdriving car', 0.010270604638319894),
#  ('uber what', 0.010270604638319894),
#  ('who drove', 0.010270604638319894),
#  ('truck driver', 0.010270604638319894),
#  ('halts selfdriving', 0.010270604638319894)]

# %% [markdown]
# # **Model serialization**
# The model and its internal settings can easily be saved. Note that the documents and embeddings will not be saved. However, UMAP and HDBSCAN will be saved.

# %%
# Save model
topic_model.save("my_model")

# %%
# Load model
my_model = BERTopic.load("my_model")

# %% [markdown]
# # On Your Own
# 1. Use your collected 1,000 Reddit submissions.
# 2. Run BERTopic
# - Reduce outliers
# - Update topics so that it makes the best sense.
